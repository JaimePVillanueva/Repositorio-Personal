# %%
lista_valores.index("un")

# %% [markdown]
# .index() devuelve el priemr índice en el que encuentra en est ecaso el "un"

# %% [markdown]
# ### Ejercicio Sprint 02 Práctica Obligatoria

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]
lista_valores = []
lista_duplicados = []
lista_indices_dup = []
for valor in ejer_3:
    if valor.lower() in lista_valores:
        print(f"{valor} está duplicado")
        lista_duplicados.append(valor)
        lista_indices_dup.append(lista_valores.index(valor))
    lista_valores.append(valor.lower())
    print(lista_valores)

# %% [markdown]
# ### Ejercicio 2

# %%
ejer_2 = [1,2,3,4,5]
lista_cuadrados = []
for numero in ejer_2:
    lista_cuadrados.append(numero**2)
    print(f'Se añade a lista_cuadrados {numero**2}')
    print(f'Lista_cuadrados actualmente: {lista_cuadrados}')
    print('-----')

# %% [markdown]
# #### Apunte
#
# Hay muchas funciones internas en python que te pueden eivtar hacer el código más grande y te facilita la vida bastante. Por ejemplo:

# %% [markdown]
# ### Ejercicio 3

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
ejer_9.count(3)
veces = 0
for i in ejer_9:
    if i == 3:
        veces = veces + 1
veces

# %%
ejer_9.count(3) ## Cuenta todos los elmentos en la lista ejer_9 que son el número entero 3

# %%
len(ejer_9) ## Cuenta todos lo elementos de la lista ejer_9

# %%
60 in ejer_9 ## Devuelve True si hay un 60 en la lista ejer_9, si no lo hay devuelve un False

# %%
dict(enumerate(ejer_9)) ## Con esto se hace que la clave sea la posición de cada elemento de la lista ejer_9 y el valor el elemento en si de la lista ejer_9

# %% [markdown]
# ### Ejercicio 6

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
resultado = 1
for i in ejer_6.values():
    resultado *= i
    # resultado = resultado * i
    print('Resultado',resultado)

# %% [markdown]
# El break en python rompe con la secuencia por compelto pero el continue continúa. En un bucle for, el break deja de iterar, para el for por completo. Con el continue, salta a la siguiente iteración.

# %% [markdown]
# ### Ejercicio 13

# %%
def DNI_valido(dni):
    palabra='TRWAGMYFPDXBNJZSQVHLCKE'
    digito = dni[:-1]
    letra = dni[-1]
   
    chequeo = palabra[int(digito)%23]
   
    condicion1 = len(digito)  7 or len(digito)  8
    condicion2 = chequeo == letra
   
    if condicion1 and condicion2:
        return True
    return False
DNI_valido("99999999R")
